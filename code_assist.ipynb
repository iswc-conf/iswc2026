# %%
def text_to_li(text):
    lines = text.splitlines()
    return "\n".join(f"<li>{line}</li>" for line in lines if line.strip())


# Example usage
input_text = """
Abstract Submission Deadline: July 25, 2026
Full Paper Submission Deadline: Aug 1, 2026
Author Notifications: August 26, 2026
Camera-Ready Copy Due: September 1, 2026
Conference Dates: October 25–29, 2026

"""

output = text_to_li(input_text)
print(output)
# Out:
# <li>Abstract Submission Deadline: July 25, 2026</li>
# <li>Full Paper Submission Deadline: Aug 1, 2026</li>
# <li>Author Notifications: August 26, 2026</li>
# <li>Camera-Ready Copy Due: September 1, 2026</li>
# <li>Conference Dates: October 25–29, 2026</li>

# %%
with open("/home/navis/dev/iswc2026/src/components/calls/ISWC 2026 Accepted Workshops - Accepted Workshops.tsv", "r") as f:
    for line in f.readlines():
        print(line)
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
