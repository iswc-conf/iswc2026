# %%
def text_to_li(text):
    lines = text.splitlines()
    return "\n".join(f"<li>{line}</li>" for line in lines if line.strip())


# Example usage
input_text = """
Anything between 2 to 8 pages, including references.
Submissions must be formatted using the main conference template (Springer Publications format for Lecture Notes in Computer Science, LNCS). For details on the LNCS style, see Springer’s Author Instructions. For HTML submission guidance, please see the HTML submission guide.
Double-blind review
All papers will be part of the main conference proceedings 

"""

output = text_to_li(input_text)
print(output)
# Out:
# <li>How do we move past mere data-feeding pipelines to forge a unified, continuous reasoning architecture between Large Language Models and explicit semantic schemas?</li>
# <li>What are the challenges for Semantic Web protocols when the primary consumers, creators, and navigators of web semantics are autonomous GenAI agents rather than humans? Should query languages and data formats change when the user looking at the data is not human anymore?</li>
# <li>In a world dominated by extremely capable AI models, what is the future of data engineering, data curation?</li>
# <li>Can semantic web paradigms facilitate truth-grounding mechanisms to mitigate hallucinations, authenticate provenance, and enforce accountability across synthetic media ecosystems?</li>
# <li>Rationale-driven evaluations of which early / prior Semantic Web visions failed to achieve mass adoption, paired with the precise architectural shifts needed to revive, revise, or replace them today.</li>

# %%
with open("/home/navis/dev/iswc2026/src/components/calls/ISWC 2026 Accepted Workshops - Accepted Workshops.tsv", "r") as f:
    for line in f.readlines():
        print(line)
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
