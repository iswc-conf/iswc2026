# %%
def text_to_li(text):
    lines = text.splitlines()
    return "\n".join(f"<li>{line}</li>" for line in lines if line.strip())


# Example usage
input_text = """
Abstract submission due	May 2nd, 2026
Full paper submission due	May 7th, 2026
Rebuttal			May 28th - June 3rd, 2026
Notifications			June 24th, 2026
Camera-ready papers due	July 8th, 2026
Conference:			27 - 29 October 2026
"""

output = text_to_li(input_text)
print(output)
# Out:
# <li>Abstract submission due	May 2nd, 2026</li>
# <li>Full paper submission due	May 7th, 2026</li>
# <li>Rebuttal			May 28th - June 3rd, 2026</li>
# <li>Notifications			June 24th, 2026</li>
# <li>Camera-ready papers due	July 8th, 2026</li>
# <li>Conference:			27 - 29 October 2026</li>
